# %%
import pandas as panda
from matplotlib import pyplot as plot
import numpy as np
import seaborn as sns

# %%
train_data  = panda.read_csv('all_new/merchants.csv')

# %%
train_data.shape, train_data.merchant_id.unique().shape
# Out:
# ((334696, 22), (334633,))

# %%
train_data.describe(include='all').T
# Out:
#                               count  unique              top    freq  \
# merchant_id                  334696  334633  M_ID_6464db3b45       4
# merchant_group_id            334696     NaN              NaN     NaN
# merchant_category_id         334696     NaN              NaN     NaN
# subsector_id                 334696     NaN              NaN     NaN
# numerical_1                  334696     NaN              NaN     NaN
# numerical_2                  334696     NaN              NaN     NaN
# category_1                   334696       2                N  327657
# most_recent_sales_range      334696       5                E  177104
# most_recent_purchases_range  334696       5                E  175309
# avg_sales_lag3               334683     NaN              NaN     NaN
# avg_purchases_lag3           334696     NaN              NaN     NaN
# active_months_lag3           334696     NaN              NaN     NaN
# avg_sales_lag6               334683     NaN              NaN     NaN
# avg_purchases_lag6           334696     NaN              NaN     NaN
# active_months_lag6           334696     NaN              NaN     NaN
# avg_sales_lag12              334683     NaN              NaN     NaN
# avg_purchases_lag12          334696     NaN              NaN     NaN
# active_months_lag12          334696     NaN              NaN     NaN
# category_4                   334696       2                N  238596
# city_id                      334696     NaN              NaN     NaN
# state_id                     334696     NaN              NaN     NaN
# category_2                   322809     NaN              NaN     NaN
#
#                                    mean        std        min        25%  \
# merchant_id                         NaN        NaN        NaN        NaN
# merchant_group_id               31028.7      31623          1       3612
# merchant_category_id            423.132    252.898         -1        222
# subsector_id                    25.1164    9.80737         -1         19
# numerical_1                   0.0114764    1.09815 -0.0574706 -0.0574706
# numerical_2                  0.00810311     1.0705 -0.0574706 -0.0574706
# category_1                          NaN        NaN        NaN        NaN
# most_recent_sales_range             NaN        NaN        NaN        NaN
# most_recent_purchases_range         NaN        NaN        NaN        NaN
# avg_sales_lag3                   13.833    2395.49     -82.13       0.88
# avg_purchases_lag3                  inf        NaN   0.333495    0.92365
# active_months_lag3              2.99411  0.0952475          1          3
# avg_sales_lag6                  21.6508    3947.11     -82.13       0.85
# avg_purchases_lag6                  inf        NaN   0.167045   0.902247
# active_months_lag6               5.9474   0.394936          1          6
# avg_sales_lag12                 25.2277    5251.84     -82.13       0.85
# avg_purchases_lag12                 inf        NaN  0.0983295   0.898333
# active_months_lag12             11.5993    1.52014          1         12
# category_4                          NaN        NaN        NaN        NaN
# city_id                         102.918    107.091         -1         -1
# state_id                        11.8609    6.17689         -1          9
# category_2                         2.38    1.56266          1          1
#
#                                    50%        75%          max
# merchant_id                        NaN        NaN          NaN
# merchant_group_id                19900    51707.2       112586
# merchant_category_id               373        683          891
# subsector_id                        27         33           41
# numerical_1                 -0.0574706 -0.0475558      183.735
# numerical_2                 -0.0574706 -0.0475558      182.079
# category_1                         NaN        NaN          NaN
# most_recent_sales_range            NaN        NaN          NaN
# most_recent_purchases_range        NaN        NaN          NaN
# avg_sales_lag3                       1       1.16       851845
# avg_purchases_lag3             1.01667    1.14652          inf
# active_months_lag3                   3          3            3
# avg_sales_lag6                    1.01       1.23  1.51396e+06
# avg_purchases_lag6             1.02696    1.21558          inf
# active_months_lag6                   6          6            6
# avg_sales_lag12                   1.02       1.29  2.56741e+06
# avg_purchases_lag12            1.04336    1.26648          inf
# active_months_lag12                 12         12           12
# category_4                         NaN        NaN          NaN
# city_id                             69        182          347
# state_id                             9         16           24
# category_2                           2          4            5

# %% [markdown]
# ##### We can observe the following from merchants data
#
# 1. avg_purchases_lag12,avg_purchases_lag6, avg_purchases_lag3 all have np.inf values.which would require handling.
# 2. state_id, city_id, subsector_id, merchant_category_id have minimum values as -1. these indicate missing data
#
# object data types are:
#
# 1. category_4
#
# 2. category_1
#
# 3. most_recent_sales_range
#
# 4. most_recent_purchases_range

# %%
train_data_dtypes = train_data.dtypes.to_frame().reset_index()
train_data_dtypes.columns = ['col_name','col_type']
train_data_dtypes
# Out:
#                        col_name col_type
# 0                   merchant_id   object
# 1             merchant_group_id    int64
# 2          merchant_category_id    int64
# 3                  subsector_id    int64
# 4                   numerical_1  float64
# 5                   numerical_2  float64
# 6                    category_1   object
# 7       most_recent_sales_range   object
# 8   most_recent_purchases_range   object
# 9                avg_sales_lag3  float64
# 10           avg_purchases_lag3  float64
# 11           active_months_lag3    int64
# 12               avg_sales_lag6  float64
# 13           avg_purchases_lag6  float64
# 14           active_months_lag6    int64
# 15              avg_sales_lag12  float64
# 16          avg_purchases_lag12  float64
# 17          active_months_lag12    int64
# 18                   category_4   object
# 19                      city_id    int64
# 20                     state_id    int64
# 21                   category_2  float64

# %%
train_data_dtypes[train_data_dtypes.col_type==np.object].col_name
# Out:
# 0                     merchant_id
# 6                      category_1
# 7         most_recent_sales_range
# 8     most_recent_purchases_range
# 18                     category_4
# Name: col_name, dtype: object

# %%
# ignoring merchant id lets analyze the rest of the fields such as category_1,most_recent_sales_range,most_recent_purchase_range,
# category_4

# check for empty values
train_data[train_data_dtypes[train_data_dtypes.col_type==np.object].col_name.values.tolist()].isnull().sum()
# Out:
# merchant_id                    0
# category_1                     0
# most_recent_sales_range        0
# most_recent_purchases_range    0
# category_4                     0
# dtype: int64

# %%
train_data.category_1.value_counts()
# Out:
# N    327657
# Y      7039
# Name: category_1, dtype: int64

# %%
train_data['merchant_category_1_yes'] = train_data.category_1.apply(lambda x : 1 if x=='Y'else 0).astype(np.int64)
train_data['merchant_category_1_no'] = train_data.category_1.apply(lambda x : 1 if x=='N'else 0).astype(np.int64)

# %%
train_data.category_4.value_counts()
# Out:
# N    238596
# Y     96100
# Name: category_4, dtype: int64

# %%
train_data['merchant_category_4_yes'] = train_data.category_4.apply(lambda x : 1 if x=='Y'else 0).astype(np.int64)
train_data['merchant_category_4_no'] = train_data.category_4.apply(lambda x : 1 if x=='N'else 0).astype(np.int64)

# %%
train_data.most_recent_sales_range.value_counts()
# Out:
# E    177104
# D    117475
# C     34075
# B      5037
# A      1005
# Name: most_recent_sales_range, dtype: int64

# %%
train_data['most_sales_range_E'] = train_data.most_recent_sales_range.apply(lambda x : 1 if x=='E'else 0).astype(np.int64)
train_data['most_sales_range_D'] = train_data.most_recent_sales_range.apply(lambda x : 1 if x=='D'else 0).astype(np.int64)
train_data['most_sales_range_C'] = train_data.most_recent_sales_range.apply(lambda x : 1 if x=='C'else 0).astype(np.int64)
train_data['most_sales_range_B'] = train_data.most_recent_sales_range.apply(lambda x : 1 if x=='B'else 0).astype(np.int64)
train_data['most_sales_range_A'] = train_data.most_recent_sales_range.apply(lambda x : 1 if x=='A'else 0).astype(np.int64)

# %%
train_data.most_recent_purchases_range.value_counts()
# Out:
# E    175309
# D    119187
# C     34144
# B      5046
# A      1010
# Name: most_recent_purchases_range, dtype: int64

# %%
train_data['most_recent_purchases_range_E'] = train_data.most_recent_purchases_range.apply(lambda x : 1 if x=='E'else 0).astype(np.int64)
train_data['most_recent_purchases_range_D'] = train_data.most_recent_purchases_range.apply(lambda x : 1 if x=='D'else 0).astype(np.int64)
train_data['most_recent_purchases_range_C'] = train_data.most_recent_purchases_range.apply(lambda x : 1 if x=='C'else 0).astype(np.int64)
train_data['most_recent_purchases_range_B'] = train_data.most_recent_purchases_range.apply(lambda x : 1 if x=='B'else 0).astype(np.int64)
train_data['most_recent_purchases_range_A'] = train_data.most_recent_purchases_range.apply(lambda x : 1 if x=='A'else 0).astype(np.int64)

# %%
int_col_names = train_data_dtypes[train_data_dtypes.col_type==np.int64].col_name.values.tolist()
int_col_names
# Out:
# ['merchant_group_id',
#  'merchant_category_id',
#  'subsector_id',
#  'active_months_lag3',
#  'active_months_lag6',
#  'active_months_lag12',
#  'city_id',
#  'state_id']

# %%
train_data[int_col_names].isnull().any().sum()#no empty or nan values
# Out:
# 0

# %%
##however -1 would indicate missing/outlier data for merchants ..let check the count of those

train_data[train_data.merchant_category_id==-1].shape,\
train_data[train_data.subsector_id==-1].shape,\
train_data[train_data.state_id==-1].shape,\
train_data[train_data.city_id==-1].shape,\
train_data.loc[(train_data.merchant_category_id==-1) &(train_data.subsector_id==-1)].shape,\
train_data.loc[(train_data.merchant_category_id==-1) &(train_data.subsector_id==-1)].shape,\
train_data.loc[(train_data.merchant_category_id==-1) &(train_data.subsector_id==-1)].merchant_id
# Out:
# ((1, 36),
#  (1, 36),
#  (11887, 36),
#  (105184, 36),
#  (1, 36),
#  (1, 36),
#  2465    M_ID_a2cfe4149a
#  Name: merchant_id, dtype: object)

# %% [markdown]
# I have decided not to handle -1 values as missing data in the state_id, city_id, merchant_category_id and subsector_id fields

# %%
train_data.merchant_group_id.unique()
# Out:
# array([  8353,   3184,    447, ..., 112528, 112393, 107283], dtype=int64)

# %%
train_data.merchant_category_id.unique()
# Out:
# array([792, 840, 690, 222,  87, 529, 813,  81, 369, 427,  63,  45,   2,
#        278, 298, 497, 309, 705, 511, 437, 456, 781, 703, 360, 796, 412,
#        332,  80, 630,  68, 591, 606, 683, 891, 560, 178, 290, 544, 823,
#        692, 779,  33, 432, 818, 819, 842, 411,  19, 771,  34, 419, 884,
#        184, 111, 434, 356, 367, 373, 631, 573, 652, 669, 531, 195, 130,
#        836, 637, 670, 307, 215, 387, 506, 443, 774, 414, 166, 108, 607,
#        451, 763, 806, 471, 518, 105,  60, 391, 557, 302, 154, 623, 333,
#        847, 384,  78, 299, 342, 363, 101, 783,  90, 489, 737, 650, 261,
#        556, 209, 454, 462,   9, 769, 561, 661, 289, 474, 180, 259,  14,
#         40, 317, 273, 115, 507, 667, 216, 498, 422, 206, 613, 430, 110,
#        574, 536, 653, 357, 274, 793, 171, 385, 472, 651,  56, 312, 119,
#        201, 247, 554, 114, 873, 671, 190, 854, 530, 843, 527, 761, 320,
#        276, 348, 743, 109, 315, 645,  16, 834, 415, 642,  83, 568,  49,
#        223, 695, 696, 172, 702, 458, 748, 416, 330, 706, 340,  21, 469,
#        267, 181, 225, 795, 241, 157, 605, 808, 734, 396,  71, 420, 145,
#        409, 751,  52,  69, 717, 598, 246, 827, 551, 417, 345, 519, 265,
#        504, 117, 480, 351, 482, 491, 513,  57, 580, 676,  -1, 614, 457,
#        879,  18, 514, 593, 248, 210, 179, 685, 319, 126, 713, 383, 374,
#        829, 534, 686, 755, 386, 478, 526, 198, 776, 839,  36, 401,  53,
#        358, 268,  31, 162, 528, 187, 509, 224, 499, 140, 665, 542, 245,
#         38, 398, 183, 587, 292, 438, 343, 656, 889, 803, 664, 400, 523,
#        712, 814, 790, 393, 546, 662, 885, 266, 805, 881, 334, 131, 355,
#        249, 628, 448, 566,  11, 141, 421, 599, 226, 322,  86, 260, 601,
#        634, 281, 550, 757, 217, 741, 780, 714,  59, 436, 668,  67, 164,
#        464, 381, 182, 579, 648, 718, 153, 725, 875, 789, 878, 583],
#       dtype=int64)

# %%
temp = train_data.groupby(['merchant_id']).agg({'merchant_category_id':'nunique'}).reset_index()
temp[temp.merchant_category_id!=1]

##merchant and merchant cat id is a 1-many relationship
# Out:
#             merchant_id  merchant_category_id
# 130891  M_ID_645a6af169                     2

# %%
int_col_names
# Out:
# ['merchant_group_id',
#  'merchant_category_id',
#  'subsector_id',
#  'active_months_lag3',
#  'active_months_lag6',
#  'active_months_lag12',
#  'city_id',
#  'state_id']

# %%
train_data.subsector_id.unique(),train_data.city_id.unique(),train_data.state_id.unique()
# Out:
# (array([ 9, 20,  1, 21, 27, 29, 18, 37, 10, 33,  7, 15, 34,  2, 36, 17, 19,
#         25, 12, 31, 38, 40, 32, 16, 41,  5, 30, 13, 22,  4, 23, 39,  8, 14,
#          3, 26, 35, 24, -1, 11, 28], dtype=int64),
#  array([242,  22,  -1, 160,  60, 248,  88, 158,  11, 143, 282, 123, 126,
#         272,  85, 140,  62,  63, 323, 200, 310,  69, 239,  17,   4, 231,
#         124,   3, 301,  87, 186, 150, 156, 161, 209,  25, 303, 101,  12,
#         147,  44, 254,  58,  32,  53,  96, 213, 214, 125, 229, 168,  30,
#         204,  94, 210, 137, 165, 187, 223, 238, 205, 157, 114, 276,  76,
#         233, 183, 277, 212, 247, 167, 274, 343, 251, 283,   9,  21,  84,
#           7, 297, 291,  33, 246, 169, 228, 201, 181, 253, 159, 172,  47,
#           6, 113, 206,  51,  82,  80,  36, 215, 259, 314,  98, 295, 174,
#         211, 339, 250, 307,  24,  48,  89, 341, 275,  66, 224, 189, 230,
#         100, 142, 342, 135, 105, 115,  64, 153, 245, 299,  14, 184, 208,
#         235, 219, 108, 119, 329, 163, 139, 220,  52,  10, 285, 337, 308,
#         300, 155, 256, 271,   1, 333, 116, 136, 281,  56, 218,   8, 340,
#         261, 146,  38, 106,  46, 325,  42, 226, 268,  90, 129, 289, 270,
#          91, 130, 311, 216, 294, 278, 171, 336, 117, 148, 255, 288, 180,
#         318, 203, 260, 110, 334,  41,  61, 232, 327, 151, 240,  78, 262,
#          39, 166,  49,  23, 221,  97, 191, 128,  65, 133, 252, 190, 258,
#         296,  16, 193, 293, 287,  70, 321, 131, 269, 236, 198, 309, 188,
#          34, 175, 306, 347, 112, 234,  28,  86, 290, 267,  29,   2, 313,
#          74,  68, 279, 182,  71, 338, 162, 104,  81,  83, 194, 144, 312,
#          13,  26, 326, 328, 263, 145, 304, 345, 173, 286, 265, 120, 178,
#         111,  40,  77, 237,  73,  35,  92, 118, 330,  18, 320], dtype=int64),
#  array([ 9, 16,  5, -1, 21, 15, 20, 23, 18, 19,  4,  8,  1,  2, 22,  7,  6,
#         13, 10, 24, 11, 14,  3, 12, 17], dtype=int64))

# %%
train_data.active_months_lag3.nunique(),train_data.active_months_lag6.nunique(),train_data.active_months_lag12.nunique()
# Out:
# (3, 6, 12)

# %%
float_col_names = train_data_dtypes[train_data_dtypes.col_type==np.float64].col_name.values.tolist()
float_col_names
# Out:
# ['numerical_1',
#  'numerical_2',
#  'avg_sales_lag3',
#  'avg_purchases_lag3',
#  'avg_sales_lag6',
#  'avg_purchases_lag6',
#  'avg_sales_lag12',
#  'avg_purchases_lag12',
#  'category_2']

# %%
train_data[float_col_names].isnull().sum()
# Out:
# numerical_1                0
# numerical_2                0
# avg_sales_lag3            13
# avg_purchases_lag3         0
# avg_sales_lag6            13
# avg_purchases_lag6         0
# avg_sales_lag12           13
# avg_purchases_lag12        0
# category_2             11887
# dtype: int64

# %%
mean_avg_sales_3 = np.mean(train_data[~train_data.avg_sales_lag3.isna()].avg_sales_lag3.values)
mean_avg_sales_6 = np.mean(train_data[~train_data.avg_sales_lag6.isna()].avg_sales_lag6.values)
mean_avg_sales_12 = np.mean(train_data[~train_data.avg_sales_lag12.isna()].avg_sales_lag12.values)

# %%
train_data.avg_sales_lag3.fillna(value= mean_avg_sales_3, inplace = True)
train_data.avg_sales_lag6.fillna(value= mean_avg_sales_6, inplace = True)
train_data.avg_sales_lag12.fillna(value= mean_avg_sales_12, inplace = True)

# %%
train_data.numerical_1.unique(),train_data.numerical_2.unique()#no idea what these negative numbers are
# Out:
# (array([-5.74706500e-02, -7.89613000e-03,  4.08529850e-01, -4.75557500e-02,
#          4.98045834e+01,  2.96773275e+01,  4.48768759e+01,  7.01896267e+01,
#          5.41671413e+01,  5.33838638e+01,  3.97806150e+01,  4.17933406e+01,
#          8.06895104e+01,  5.88469761e+01,  4.03061050e+01,  4.11092122e+01,
#          8.12744898e+01,  4.80595602e+01,  6.35069812e+01,  9.91808070e+01,
#          6.47959187e+01,  1.46881412e+02,  5.66557823e+01,  6.69573679e+01,
#          7.96781902e+01,  1.04901707e+02,  1.28548754e+02,  1.82079322e+02,
#          1.07132560e+02,  1.16888826e+02,  1.70736672e+02]))

# %%
train_data[float_col_names].isnull().sum()
# Out:
# numerical_1                0
# numerical_2                0
# avg_sales_lag3             0
# avg_purchases_lag3         0
# avg_sales_lag6             0
# avg_purchases_lag6         0
# avg_sales_lag12            0
# avg_purchases_lag12        0
# category_2             11887
# dtype: int64

# %%
most_appearing = train_data.category_2.value_counts().idxmax()
train_data.category_2.fillna(value=most_appearing, inplace= True)

# %%
train_data.describe(include='all').T
# Out:
#                                 count  unique              top    freq  \
# merchant_id                    334696  334633  M_ID_6464db3b45       4
# merchant_group_id              334696     NaN              NaN     NaN
# merchant_category_id           334696     NaN              NaN     NaN
# subsector_id                   334696     NaN              NaN     NaN
# numerical_1                    334696     NaN              NaN     NaN
# numerical_2                    334696     NaN              NaN     NaN
# category_1                     334696       2                N  327657
# most_recent_sales_range        334696       5                E  177104
# most_recent_purchases_range    334696       5                E  175309
# avg_sales_lag3                 334696     NaN              NaN     NaN
# avg_purchases_lag3             334696     NaN              NaN     NaN
# active_months_lag3             334696     NaN              NaN     NaN
# avg_sales_lag6                 334696     NaN              NaN     NaN
# avg_purchases_lag6             334696     NaN              NaN     NaN
# active_months_lag6             334696     NaN              NaN     NaN
# avg_sales_lag12                334696     NaN              NaN     NaN
# avg_purchases_lag12            334696     NaN              NaN     NaN
# active_months_lag12            334696     NaN              NaN     NaN
# category_4                     334696       2                N  238596
# city_id                        334696     NaN              NaN     NaN
# state_id                       334696     NaN              NaN     NaN
# category_2                     334696     NaN              NaN     NaN
# merchant_category_1_yes        334696     NaN              NaN     NaN
# merchant_category_1_no         334696     NaN              NaN     NaN
# merchant_category_4_yes        334696     NaN              NaN     NaN
# merchant_category_4_no         334696     NaN              NaN     NaN
# most_sales_range_E             334696     NaN              NaN     NaN
# most_sales_range_D             334696     NaN              NaN     NaN
# most_sales_range_C             334696     NaN              NaN     NaN
# most_sales_range_B             334696     NaN              NaN     NaN
# most_sales_range_A             334696     NaN              NaN     NaN
# most_recent_purchases_range_E  334696     NaN              NaN     NaN
# most_recent_purchases_range_D  334696     NaN              NaN     NaN
# most_recent_purchases_range_C  334696     NaN              NaN     NaN
# most_recent_purchases_range_B  334696     NaN              NaN     NaN
# most_recent_purchases_range_A  334696     NaN              NaN     NaN
#
#                                      mean        std        min        25%  \
# merchant_id                           NaN        NaN        NaN        NaN
# merchant_group_id                 31028.7      31623          1       3612
# merchant_category_id              423.132    252.898         -1        222
# subsector_id                      25.1164    9.80737         -1         19
# numerical_1                     0.0114764    1.09815 -0.0574706 -0.0574706
# numerical_2                    0.00810311     1.0705 -0.0574706 -0.0574706
# category_1                            NaN        NaN        NaN        NaN
# most_recent_sales_range               NaN        NaN        NaN        NaN
# most_recent_purchases_range           NaN        NaN        NaN        NaN
# avg_sales_lag3                     13.833    2395.44     -82.13       0.88
# avg_purchases_lag3                    inf        NaN   0.333495    0.92365
# active_months_lag3                2.99411  0.0952475          1          3
# avg_sales_lag6                    21.6508    3947.03     -82.13       0.85
# avg_purchases_lag6                    inf        NaN   0.167045   0.902247
# active_months_lag6                 5.9474   0.394936          1          6
# avg_sales_lag12                   25.2277    5251.74     -82.13       0.85
# avg_purchases_lag12                   inf        NaN  0.0983295   0.898333
# active_months_lag12               11.5993    1.52014          1         12
# category_4                            NaN        NaN        NaN        NaN
# city_id                           102.918    107.091         -1         -1
# state_id                          11.8609    6.17689         -1          9
# category_2                        2.33099    1.55577          1          1
# merchant_category_1_yes          0.021031   0.143488          0          0
# merchant_category_1_no           0.978969   0.143488          0          1
# merchant_category_4_yes          0.287126   0.452422          0          0
# merchant_category_4_no           0.712874   0.452422          0          0
# most_sales_range_E               0.529149    0.49915          0          0
# most_sales_range_D                0.35099   0.477281          0          0
# most_sales_range_C               0.101809   0.302397          0          0
# most_sales_range_B              0.0150495    0.12175          0          0
# most_sales_range_A             0.00300272  0.0547149          0          0
# most_recent_purchases_range_E    0.523786   0.499435          0          0
# most_recent_purchases_range_D    0.356105   0.478848          0          0
# most_recent_purchases_range_C    0.102015   0.302668          0          0
# most_recent_purchases_range_B   0.0150764   0.121857          0          0
# most_recent_purchases_range_A  0.00301766  0.0548504          0          0
#
#                                      50%        75%          max
# merchant_id                          NaN        NaN          NaN
# merchant_group_id                  19900    51707.2       112586
# merchant_category_id                 373        683          891
# subsector_id                          27         33           41
# numerical_1                   -0.0574706 -0.0475558      183.735
# numerical_2                   -0.0574706 -0.0475558      182.079
# category_1                           NaN        NaN          NaN
# most_recent_sales_range              NaN        NaN          NaN
# most_recent_purchases_range          NaN        NaN          NaN
# avg_sales_lag3                         1       1.16       851845
# avg_purchases_lag3               1.01667    1.14652          inf
# active_months_lag3                     3          3            3
# avg_sales_lag6                      1.01       1.23  1.51396e+06
# avg_purchases_lag6               1.02696    1.21558          inf
# active_months_lag6                     6          6            6
# avg_sales_lag12                     1.02       1.29  2.56741e+06
# avg_purchases_lag12              1.04336    1.26648          inf
# active_months_lag12                   12         12           12
# category_4                           NaN        NaN          NaN
# city_id                               69        182          347
# state_id                               9         16           24
# category_2                             1          4            5
# merchant_category_1_yes                0          0            1
# merchant_category_1_no                 1          1            1
# merchant_category_4_yes                0          1            1
# merchant_category_4_no                 1          1            1
# most_sales_range_E                     1          1            1
# most_sales_range_D                     0          1            1
# most_sales_range_C                     0          0            1
# most_sales_range_B                     0          0            1
# most_sales_range_A                     0          0            1
# most_recent_purchases_range_E          1          1            1
# most_recent_purchases_range_D          0          1            1
# most_recent_purchases_range_C          0          0            1
# most_recent_purchases_range_B          0          0            1
# most_recent_purchases_range_A          0          0            1

# %%
train_data.drop(columns = ['most_recent_sales_range','most_recent_purchases_range'], inplace = True)

# %%
avg_purchases_lag3_mean = np.mean(train_data[train_data.avg_purchases_lag3!=np.inf].avg_purchases_lag3.values)
avg_purchases_lag6_mean = np.mean(train_data[train_data.avg_purchases_lag6!=np.inf].avg_purchases_lag6.values)
avg_purchases_lag12_mean = np.mean(train_data[train_data.avg_purchases_lag12!=np.inf].avg_purchases_lag12.values)
avg_purchases_lag3_mean,avg_purchases_lag6_mean,avg_purchases_lag12_mean
# Out:
# (1.5907620965243672, 1.8875678157761595, 2.0791954108497936)

# %%
train_data.avg_purchases_lag3.replace(np.inf , avg_purchases_lag3_mean, inplace = True)
train_data.avg_purchases_lag6.replace(np.inf , avg_purchases_lag6_mean, inplace = True)
train_data.avg_purchases_lag12.replace(np.inf , avg_purchases_lag12_mean, inplace = True)

# %%
train_data.describe(include='all').T
# Out:
#                                 count  unique              top    freq  \
# merchant_id                    334696  334633  M_ID_6464db3b45       4
# merchant_group_id              334696     NaN              NaN     NaN
# merchant_category_id           334696     NaN              NaN     NaN
# subsector_id                   334696     NaN              NaN     NaN
# numerical_1                    334696     NaN              NaN     NaN
# numerical_2                    334696     NaN              NaN     NaN
# category_1                     334696       2                N  327657
# avg_sales_lag3                 334696     NaN              NaN     NaN
# avg_purchases_lag3             334696     NaN              NaN     NaN
# active_months_lag3             334696     NaN              NaN     NaN
# avg_sales_lag6                 334696     NaN              NaN     NaN
# avg_purchases_lag6             334696     NaN              NaN     NaN
# active_months_lag6             334696     NaN              NaN     NaN
# avg_sales_lag12                334696     NaN              NaN     NaN
# avg_purchases_lag12            334696     NaN              NaN     NaN
# active_months_lag12            334696     NaN              NaN     NaN
# category_4                     334696       2                N  238596
# city_id                        334696     NaN              NaN     NaN
# state_id                       334696     NaN              NaN     NaN
# category_2                     334696     NaN              NaN     NaN
# merchant_category_1_yes        334696     NaN              NaN     NaN
# merchant_category_1_no         334696     NaN              NaN     NaN
# merchant_category_4_yes        334696     NaN              NaN     NaN
# merchant_category_4_no         334696     NaN              NaN     NaN
# most_sales_range_E             334696     NaN              NaN     NaN
# most_sales_range_D             334696     NaN              NaN     NaN
# most_sales_range_C             334696     NaN              NaN     NaN
# most_sales_range_B             334696     NaN              NaN     NaN
# most_sales_range_A             334696     NaN              NaN     NaN
# most_recent_purchases_range_E  334696     NaN              NaN     NaN
# most_recent_purchases_range_D  334696     NaN              NaN     NaN
# most_recent_purchases_range_C  334696     NaN              NaN     NaN
# most_recent_purchases_range_B  334696     NaN              NaN     NaN
# most_recent_purchases_range_A  334696     NaN              NaN     NaN
#
#                                      mean        std        min        25%  \
# merchant_id                           NaN        NaN        NaN        NaN
# merchant_group_id                 31028.7      31623          1       3612
# merchant_category_id              423.132    252.898         -1        222
# subsector_id                      25.1164    9.80737         -1         19
# numerical_1                     0.0114764    1.09815 -0.0574706 -0.0574706
# numerical_2                    0.00810311     1.0705 -0.0574706 -0.0574706
# category_1                            NaN        NaN        NaN        NaN
# avg_sales_lag3                     13.833    2395.44     -82.13       0.88
# avg_purchases_lag3                1.59076    107.187   0.333495    0.92365
# active_months_lag3                2.99411  0.0952475          1          3
# avg_sales_lag6                    21.6508    3947.03     -82.13       0.85
# avg_purchases_lag6                1.88757    97.8624   0.167045   0.902247
# active_months_lag6                 5.9474   0.394936          1          6
# avg_sales_lag12                   25.2277    5251.74     -82.13       0.85
# avg_purchases_lag12                2.0792     88.442  0.0983295   0.898333
# active_months_lag12               11.5993    1.52014          1         12
# category_4                            NaN        NaN        NaN        NaN
# city_id                           102.918    107.091         -1         -1
# state_id                          11.8609    6.17689         -1          9
# category_2                        2.33099    1.55577          1          1
# merchant_category_1_yes          0.021031   0.143488          0          0
# merchant_category_1_no           0.978969   0.143488          0          1
# merchant_category_4_yes          0.287126   0.452422          0          0
# merchant_category_4_no           0.712874   0.452422          0          0
# most_sales_range_E               0.529149    0.49915          0          0
# most_sales_range_D                0.35099   0.477281          0          0
# most_sales_range_C               0.101809   0.302397          0          0
# most_sales_range_B              0.0150495    0.12175          0          0
# most_sales_range_A             0.00300272  0.0547149          0          0
# most_recent_purchases_range_E    0.523786   0.499435          0          0
# most_recent_purchases_range_D    0.356105   0.478848          0          0
# most_recent_purchases_range_C    0.102015   0.302668          0          0
# most_recent_purchases_range_B   0.0150764   0.121857          0          0
# most_recent_purchases_range_A  0.00301766  0.0548504          0          0
#
#                                      50%        75%          max
# merchant_id                          NaN        NaN          NaN
# merchant_group_id                  19900    51707.2       112586
# merchant_category_id                 373        683          891
# subsector_id                          27         33           41
# numerical_1                   -0.0574706 -0.0475558      183.735
# numerical_2                   -0.0574706 -0.0475558      182.079
# category_1                           NaN        NaN          NaN
# avg_sales_lag3                         1       1.16       851845
# avg_purchases_lag3               1.01667    1.14652      61851.3
# active_months_lag3                     3          3            3
# avg_sales_lag6                      1.01       1.23  1.51396e+06
# avg_purchases_lag6               1.02696    1.21558      56077.5
# active_months_lag6                     6          6            6
# avg_sales_lag12                     1.02       1.29  2.56741e+06
# avg_purchases_lag12              1.04336    1.26648      50215.6
# active_months_lag12                   12         12           12
# category_4                           NaN        NaN          NaN
# city_id                               69        182          347
# state_id                               9         16           24
# category_2                             1          4            5
# merchant_category_1_yes                0          0            1
# merchant_category_1_no                 1          1            1
# merchant_category_4_yes                0          1            1
# merchant_category_4_no                 1          1            1
# most_sales_range_E                     1          1            1
# most_sales_range_D                     0          1            1
# most_sales_range_C                     0          0            1
# most_sales_range_B                     0          0            1
# most_sales_range_A                     0          0            1
# most_recent_purchases_range_E          1          1            1
# most_recent_purchases_range_D          0          1            1
# most_recent_purchases_range_C          0          0            1
# most_recent_purchases_range_B          0          0            1
# most_recent_purchases_range_A          0          0            1

# %%
train_data.to_csv('all_new/merchants_2.csv', index = False)
