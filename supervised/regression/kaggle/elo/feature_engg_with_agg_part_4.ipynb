# %% [markdown]
# # RE RE RE FEATURE ENGINEERING OF DATA - applying transform

# %%
import numpy as np
import pandas as panda
from dateutil import relativedelta
import datetime

# %%
train_data_path = 'all_new/train.csv'
test_data_path = 'all_new/test.csv'

new_treated_transaction_path = 'all_new/treated_new_transaction_2.csv'
treated_historical_transaction_path = 'all_new/treated_historical_transaction_2.csv'

# %%
new_data = panda.read_csv(new_treated_transaction_path)
# old_data = panda.read_csv(treated_historical_transaction_path)

# %%
train_data = panda.read_csv(train_data_path)

# %%
train_data.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target
# 0 -0.820283
# 1  0.392913
# 2  0.688056
# 3  0.142495
# 4 -0.159749

# %%
# new_data.rename(columns={'new_category_2_B_sum':'new_category_3_B_sum'}, inplace=True)
new_data.columns.tolist()
# Out:
# ['authorized_flag',
#  'card_id',
#  'city_id',
#  'category_1',
#  'installments',
#  'merchant_category_id',
#  'month_lag',
#  'purchase_amount',
#  'state_id',
#  'subsector_id',
#  'enc_category_2_1',
#  'enc_category_2_2',
#  'enc_category_2_3',
#  'enc_category_2_4',
#  'enc_category_2_5',
#  'enc_category_3_A',
#  'enc_category_3_B',
#  'enc_category_3_C',
#  'enc_purchase_date',
#  'new_purchase_amount_sum',
#  'new_purchase_amount_mean',
#  'new_purchase_amount_max',
#  'new_month_lag_sum',
#  'new_month_lag_mean',
#  'new_month_lag_max',
#  'new_category_2_1_sum',
#  'new_category_2_2_sum',
#  'new_category_2_3_sum',
#  'new_category_2_4_sum',
#  'new_category_2_5_sum',
#  'new_category_3_A_sum',
#  'new_category_2_B_sum',
#  'new_category_3_C_sum',
#  'new_installments_sum',
#  'new_installments_mean',
#  'new_installments_max',
#  'new_authorized_flag_mean',
#  'new_authorized_flag_count_authorized_one',
#  'new_authorized_flag_count_authorized_zero',
# ...

# %%
len(train_data)
# Out:
# 201917

# %%
t = panda.concat([train_data,new_data], axis =1)
len(t)
# Out:
# 1963031

# %%
t.dropna(inplace= True)
len(t)
# Out:
# 201917

# %%
t.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557        5.0        2.0        1.0
# 1            2017-01  C_ID_3d0044924f        4.0        1.0        0.0
# 2            2016-08  C_ID_d639edf6cd        2.0        2.0        0.0
# 3            2017-09  C_ID_186d6a6901        4.0        3.0        0.0
# 4            2017-11  C_ID_cdbd2c0db2        1.0        3.0        0.0
#
#      target  authorized_flag          card_id  city_id  category_1  \
# 0 -0.820283                1  C_ID_415bb3a509      107           0
# 1  0.392913                1  C_ID_415bb3a509      140           0
# 2  0.688056                1  C_ID_415bb3a509      330           0
# 3  0.142495                1  C_ID_415bb3a509       69           1
# 4 -0.159749                1  C_ID_ef55cf8d4b       69           1
#
#              ...             new_authorized_flag_count_authorized_zero  \
# ...

# %%
train_data = t.copy()

# %%
train_data.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557        5.0        2.0        1.0
# 1            2017-01  C_ID_3d0044924f        4.0        1.0        0.0
# 2            2016-08  C_ID_d639edf6cd        2.0        2.0        0.0
# 3            2017-09  C_ID_186d6a6901        4.0        3.0        0.0
# 4            2017-11  C_ID_cdbd2c0db2        1.0        3.0        0.0
#
#      target  authorized_flag          card_id  city_id  category_1  \
# 0 -0.820283                1  C_ID_415bb3a509      107           0
# 1  0.392913                1  C_ID_415bb3a509      140           0
# 2  0.688056                1  C_ID_415bb3a509      330           0
# 3  0.142495                1  C_ID_415bb3a509       69           1
# 4 -0.159749                1  C_ID_ef55cf8d4b       69           1
#
#              ...             new_authorized_flag_count_authorized_zero  \
# ...

# %%
del t

# %%
del new_data

# %%
import gc
gc.collect()
# Out:
# 0

# %%
old_data = panda.read_csv(treated_historical_transaction_path)

# %%
t = panda.concat([train_data,old_data], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-13-868c93c887b3> in <module>()
# ----> 1 t = panda.concat([train_data,old_data], axis = 1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     224                        verify_integrity=verify_integrity,
#     225                        copy=copy, sort=sort)
# --> 226     return op.get_result()
#     227
#     228
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     421             new_data = concatenate_block_managers(
#     422                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 423                 copy=self.copy)
#     424             if not self.copy:
#     425                 new_data._consolidate_inplace()
#
# ...

# %%
t.dropna(inplace=True)
len(t)
# t.to_csv('all_new/train_1.csv')
